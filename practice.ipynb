# %%
print "This iz python"
# Out:
# This iz python

# %%
import numpy as np
from __future__ import print_function

# %%
# a vector: the argument to the array function is a Python list
v = np.array([11, 12, 13, 14])
print('v =\n{}'.format(v))
# a matrix: the argument to the array function is a nested Python list
M = np.array([[2, 1], [3, 4]])
print('M =\n{}'.format(M))
print (type(v), type(M))
# Out:
# v =
# [11 12 13 14]
# M =
# [[2 1]
#  [3 4]]
# <type 'numpy.ndarray'> <type 'numpy.ndarray'>

# %%
print("v shape is {}".format(v.shape))
print("M shape is {}".format(M.shape))
print("Data type of v is {}".format(v.dtype))
print()
print("M transpose =\n{}".format(M.T))
print()

M.sort(axis=0)
print("M sorted by column =\n{}".format(np.asarray(M)))
print()
# Out:
# v shape is (4L,)
# M shape is (2L, 2L)
# Data type of v is int32
#
# M transpose =
# [[2 3]
#  [1 4]]
#
# M sorted by column =
# [[2 1]
#  [3 4]]

# %%
print("v[0] = {}\n".format(v[0]))
print("M =\n{}\n".format(M))
print("M[1, 1] = {}\n".format(M[1,1]))
print("M[1] = {}\n".format(M[1]))
print("M[1, :] = {}\n".format(M[1, :]))
print("M[:, 1] = {}\n".format(M[:, 1]))
print("M[1, :] = 0")
M[1, :] = 0
print("M =\n{}\n".format(M))
# Out:
# v[0] = 11
#
# M =
# [[2 1]
#  [3 4]]
#
# M[1, 1] = 4
#
# M[1] = [3 4]
#
# M[1, :] = [3 4]
#
# M[:, 1] = [1 4]
#
# M[1, :] = 0
# M =
# [[2 1]
#  [0 0]]

# %%
import pandas.io.data
df = pd.read_csv('country-data.csv', index_col='Country Name')
df.head()
# Out:
#              Country Code          Government Type      Capital City  \
# Country Name
# Afghanistan            AF         Islamic republic             Kabul
# Albania                AL  parliamentary democracy            Tirana
# Algeria                DZ                 republic           Algiers
# Andorra                AD  parliamentary democracy  Andorra la Vella
# Angola                 AO                 republic            Luanda
#
#              Date of Founding/Independence Latitude of Capital  \
# Country Name
# Afghanistan                      8/19/1919             34 31 N
# Albania                         11/28/1912             41 19 N
# Algeria                           7/5/1962             36 45 N
# Andorra                               1278             42 30 N
# Angola                          11/11/1975              8 50 S
#
#              Longitude of Capital  Population  Life Expectancy  \
# Country Name
# Afghanistan               69 11 E    31822848            50.49
# Albania                   19 49 E     3020209            77.96
# Algeria                    3 03 E    38813722            76.39
# Andorra                    1 31 E       85458            82.65
# Angola                    13 13 E    19088106            55.29
#
#               GDP (PPP) in US $  Area (sq km)  Land Boundaries (km)  \
# Country Name
# Afghanistan        4.530000e+10        652230                  5987
# Albania            2.834000e+10         28748                   691
# Algeria            2.850000e+11       2381741                  6734
# Andorra            3.163000e+09           468                   118
# Angola             1.320000e+11       1246700                  5369
#
#               Coastline (km)  Literacy Rate  Health Expenditure/GDP  \
# Country Name
# Afghanistan                0           28.1                     9.6
# Albania                  362           96.8                     6.3
# Algeria                  998           72.6                     3.9
# Andorra                    0          100.0                     7.2
# Angola                  1600           70.4                     3.5
#
#               Military Expenditure/GDP  Renewable Water Resources (cu km)  \
# Country Name
# Afghanistan                       4.74                              65.33
# Albania                           1.47                              41.70
# Algeria                           4.48                              11.67
# Andorra                           3.84                              65.33
# Angola                            3.63                             148.00
#
#               Net Migration Rate/1000 Population  Labor Force  \
# Country Name
# Afghanistan                                -1.83      7512000
# Albania                                    -3.31      1098000
# Algeria                                    -0.93     11150000
# Andorra                                     0.00        36060
# Angola                                      0.47      9018000
#
#               Internet Users (circa 2009)  Commercial Prime Lending Rate
# Country Name
# Afghanistan                       1000000                          15.00
# Albania                           1300000                           9.52
# Algeria                           4700000                           8.00
# Andorra                             67100                          21.50
# Angola                             606700                          15.00

# %%
from pylab import *

n = 1024
X = np.random.normal(0,1,n)
Y = np.random.normal(0,1,n)
colors = np.random.rand(n)
area =  np.pi * (15 * np.random.rand(n))**2
scatter(X,Y,s=area, c=colors, alpha=0.5)
show()

# %%
print ("Hello")
# Out:
# Hello

# %%
import pandas as pd
from scipy import stats
from pandas import Series, DataFrame

def generateZScore(colName,wgt):
    #Normalize the data frame
    dfCountries['z'+colName] = stats.zscore(dfCountries[colName])
    #shifting rightwards to make it non negative
    dfCountries['z'+colName] = dfCountries['z'+colName] + (-1 * min(dfCountries['z'+colName]))
    #Projecting the values between 0-1
    dfCountries['z'+colName] = dfCountries['z'+colName] / max(dfCountries['z'+colName])
    #Weighted Score
    dfCountries['z'+colName] = wgt_literacyrate * dfCountries['z'+colName]
    #print(dfCountries['z'+colName])
    
#Read csv File into dataFrame
dfCountries = pd.read_csv('country-data.csv')

#Declaring the weights of the factors considered for the scoring
wgt_population = -5;
wgt_lifeExpectancy = 10;
wgt_gdp = 15
wgt_coastline = 5
wgt_literacyrate = 20
wgt_water = 10
wgt_labor = 20
wgt_migration = 20
wgt_internet = 20


#Add the needed extra columns
dfCountries['Population/Area'] = dfCountries['Population']/dfCountries['Area (sq km)']
dfCountries['Labor Force/Population'] = dfCountries['Labor Force']/dfCountries['Population']
dfCountries['Internet Users/Population'] = dfCountries['Internet Users (circa 2009)']/dfCountries['Population']

#Normalize the data frame
dfCountries['zPopulation/Area'] = stats.zscore(dfCountries['Population/Area'])
#shifting rightwards to make it non negative
dfCountries['zPopulation/Area'] = dfCountries['zPopulation/Area'] + (-1 * min(dfCountries['zPopulation/Area']))
#Projecting the values between 0-1
dfCountries['zPopulation/Area'] = dfCountries['zPopulation/Area'] / max(dfCountries['zPopulation/Area'])
#Weighted Score
dfCountries['zPopulation/Area'] = wgt_population * dfCountries['zPopulation/Area']

#Normalize the data frame
dfCountries['zLife Expectancy'] = stats.zscore(dfCountries['Life Expectancy'])
#shifting rightwards to make it non negative
dfCountries['zLife Expectancy'] = dfCountries['zLife Expectancy'] + (-1 * min(dfCountries['zLife Expectancy']))
#Projecting the values between 0-1
dfCountries['zLife Expectancy'] = dfCountries['zLife Expectancy'] / max(dfCountries['zLife Expectancy'])
#Weighted Score
dfCountries['zLife Expectancy'] = wgt_lifeExpectancy * dfCountries['zLife Expectancy']

#Normalize the data frame
dfCountries['zGDP (PPP) in US $'] = stats.zscore(dfCountries['GDP (PPP) in US $'])
#shifting rightwards to make it non negative
dfCountries['zGDP (PPP) in US $'] = dfCountries['zGDP (PPP) in US $'] + (-1 * min(dfCountries['zGDP (PPP) in US $']))
#Projecting the values between 0-1
dfCountries['zGDP (PPP) in US $'] = dfCountries['zGDP (PPP) in US $'] / max(dfCountries['zGDP (PPP) in US $'])
#Weighted Score
dfCountries['zGDP (PPP) in US $'] = wgt_gdp * dfCountries['zGDP (PPP) in US $']
#dfCountries['zGDP (PPP) in US $']

#Normalize the data frame
dfCountries['zCoastline (km)'] = stats.zscore(dfCountries['Coastline (km)'])
#shifting rightwards to make it non negative
dfCountries['zCoastline (km)'] = dfCountries['zCoastline (km)'] + (-1 * min(dfCountries['zCoastline (km)']))
#Projecting the values between 0-1
dfCountries['zCoastline (km)'] = dfCountries['zCoastline (km)'] / max(dfCountries['zCoastline (km)'])
#Weighted Score
dfCountries['zCoastline (km)'] = wgt_coastline * dfCountries['zCoastline (km)']

#Normalize the data frame
dfCountries['zLiteracy Rate'] = stats.zscore(dfCountries['Literacy Rate'])
#shifting rightwards to make it non negative
dfCountries['zLiteracy Rate'] = dfCountries['zLiteracy Rate'] + (-1 * min(dfCountries['zLiteracy Rate']))
#Projecting the values between 0-1
dfCountries['zLiteracy Rate'] = dfCountries['zLiteracy Rate'] / max(dfCountries['zLiteracy Rate'])
#Weighted Score
dfCountries['zLiteracy Rate'] = wgt_literacyrate * dfCountries['zLiteracy Rate']
dfCountries['zLiteracy Rate']


generateZScore('Renewable Water Resources (cu km)',wgt_water)
generateZScore('Labor Force',wgt_labor)
generateZScore('Net Migration Rate/1000 Population',wgt_migration)
generateZScore('Internet Users/Population',wgt_internet)

dfCountries['NetScore'] = dfCountries['zPopulation/Area'] + dfCountries['zLife Expectancy'] 
dfCountries['NetScore'] = dfCountries['NetScore'] + dfCountries['zCoastline (km)'] + dfCountries['zGDP (PPP) in US $']
dfCountries['NetScore'] = dfCountries['NetScore'] + dfCountries['zLiteracy Rate']
dfCountries['NetScore'] = dfCountries['NetScore'] + dfCountries['zRenewable Water Resources (cu km)'] + dfCountries['zLabor Force']
dfCountries['NetScore'] = dfCountries['NetScore'] + dfCountries['Net Migration Rate/1000 Population'] + dfCountries['Internet Users/Population']

sort(dfCountries['NetScore'])
# Out:
# array([ -5.81090386e+00,  -9.89723792e-01,  -8.63957953e-01,
#          1.14829719e+00,   1.42026625e+00,   2.00538552e+00,
#          2.18760376e+00,   3.76519178e+00,   5.44143064e+00,
#          6.77772840e+00,   7.06404614e+00,   7.15629756e+00,
#          7.28109756e+00,   7.39883735e+00,   7.63293698e+00,
#          7.82294475e+00,   7.96858628e+00,   8.14637986e+00,
#          8.65254075e+00,   8.99286828e+00,   9.36288928e+00,
#          9.78521974e+00,   1.03820831e+01,   1.07941565e+01,
#          1.11139445e+01,   1.19512757e+01,   1.20532670e+01,
#          1.22020108e+01,   1.25936955e+01,   1.29084767e+01,
#          1.29682319e+01,   1.29909836e+01,   1.31075099e+01,
#          1.31146105e+01,   1.35281044e+01,   1.35676519e+01,
#          1.35902034e+01,   1.36847628e+01,   1.38340234e+01,
#          1.41433548e+01,   1.45268364e+01,   1.45885828e+01,
#          1.46673014e+01,   1.49369059e+01,   1.51478637e+01,
#          1.52197092e+01,   1.53980949e+01,   1.54612752e+01,
#          1.54868631e+01,   1.56682261e+01,   1.58745626e+01,
#          1.60891045e+01,   1.61674078e+01,   1.62447664e+01,
#          1.63623110e+01,   1.64535094e+01,   1.68614276e+01,
#          1.69953583e+01,   1.72644733e+01,   1.72928384e+01,
#          1.72976605e+01,   1.73609749e+01,   1.74808532e+01,
#          1.77590083e+01,   1.81532331e+01,   1.85597074e+01,
#          1.85792980e+01,   1.89830291e+01,   1.91910791e+01,
#          1.92704385e+01,   1.94095725e+01,   1.96068767e+01,
#          1.97609837e+01,   1.99800468e+01,   2.02345532e+01,
#          2.02388063e+01,   2.02445728e+01,   2.02668948e+01,
#          2.04619183e+01,   2.05204719e+01,   2.05334739e+01,
#          2.05525737e+01,   2.10037073e+01,   2.14724807e+01,
#          2.18364213e+01,   2.20164675e+01,   2.20207232e+01,
#          2.20817711e+01,   2.29125778e+01,   2.29388667e+01,
#          2.32009860e+01,   2.32157004e+01,   2.32231239e+01,
#          2.33327313e+01,   2.33928363e+01,   2.34501988e+01,
#          2.34792659e+01,   2.35436423e+01,   2.35624024e+01,
#          2.36451999e+01,   2.36916822e+01,   2.36962996e+01,
#          2.40143620e+01,   2.41057670e+01,   2.43982286e+01,
#          2.48175466e+01,   2.48537168e+01,   2.52618929e+01,
#          2.53927979e+01,   2.56315943e+01,   2.58752814e+01,
#          2.59147275e+01,   2.59496738e+01,   2.60203584e+01,
#          2.60516328e+01,   2.60821321e+01,   2.61059236e+01,
#          2.61633181e+01,   2.61846357e+01,   2.62729496e+01,
#          2.64250634e+01,   2.65034654e+01,   2.65204026e+01,
#          2.66952161e+01,   2.67157939e+01,   2.67671184e+01,
#          2.68267519e+01,   2.68743194e+01,   2.69902680e+01,
#          2.73284867e+01,   2.73358632e+01,   2.75290258e+01,
#          2.75873389e+01,   2.76979640e+01,   2.77102178e+01,
#          2.77251572e+01,   2.77605464e+01,   2.81219550e+01,
#          2.81358218e+01,   2.84786605e+01,   2.84954542e+01,
#          2.86739587e+01,   2.87906883e+01,   2.88374780e+01,
#          2.90642187e+01,   2.91632132e+01,   2.92080074e+01,
#          2.92547250e+01,   2.95280260e+01,   2.96184705e+01,
#          2.96667416e+01,   2.97596726e+01,   2.98523264e+01,
#          2.99601462e+01,   3.00096082e+01,   3.00762971e+01,
#          3.01911211e+01,   3.04986075e+01,   3.05865646e+01,
#          3.06300632e+01,   3.08294922e+01,   3.13982575e+01,
#          3.17845646e+01,   3.19213440e+01,   3.25510088e+01,
#          3.29101929e+01,   3.29727470e+01,   3.34561653e+01,
#          3.36831868e+01,   3.42944174e+01,   3.46537650e+01,
#          3.51129208e+01,   3.54678046e+01,   3.57762788e+01,
#          3.61253168e+01,   3.61629752e+01,   3.63879645e+01,
#          3.67972376e+01,   3.71122666e+01,   3.73393217e+01,
#          3.73732603e+01,   3.87007114e+01,   3.87114225e+01,
#          3.90874945e+01,   3.91878986e+01,   3.99699192e+01,
#          4.04932281e+01,   4.25059937e+01,   4.31159378e+01,
#          4.80834586e+01,   4.85771552e+01,   5.39817040e+01,
#          5.72842130e+01,   6.42785787e+01,   4.70626150e+02,
#          8.89516624e+02,   1.00215589e+03])

# %%
def generateZScore(colName,wgt):
    #Normalize the data frame
    dfCountries['z'+colName] = stats.zscore(dfCountries[colName])
    #shifting rightwards to make it non negative
    dfCountries['z'+colName] = dfCountries['z'+colName] + (-1 * min(dfCountries['z'+colName]))
    #Projecting the values between 0-1
    dfCountries['z'+colName] = dfCountries['z'+colName] / max(dfCountries['z'+colName])
    #Weighted Score
    dfCountries['z'+colName] = wgt_literacyrate * dfCountries['z'+colName]
    print(dfCountries['z'+colName])

generateZScore('Renewable Water Resources (cu km)',wgt_water)
# Out:
# 0     0.158655
# 1     0.101251
# 2     0.028301
# 3     0.158655
# 4     0.359481
# 5     0.000073
# 6     1.977364
# 7     0.018827
# 8     1.195144
# 9     0.188704
# 10    0.084198
# 11    0.000000
# 12    0.000243
# 13    2.980646
# 14    0.000146
# ...
# 182    0.158655
# 183    0.160282
# 184    0.339075
# 185    0.000316
# 186    0.357052
# 187    7.455332
# 188    0.337618
# 189    0.118669
# 190    0.158655
# 191    2.995222
# 192    2.147655
# 193    0.158655
# 194    0.005053
# 195    0.255509
# 196    0.048536
# Name: zRenewable Water Resources (cu km), Length: 197, dtype: float64

# %% [markdown]
# ####(2) Do a pairwise correlation on all pairs of variables to identify which pairs correlate the strongest and which the weakest.   Do a permutation test to determine the p-value of each observed correlation to test which are significant (what fraction of permutations produce at least this high a correlation).

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

print ("Task 2\n")
#Read csv File into dataFrame
dfCountries = pd.read_csv('country-data.csv', index_col='Country Name')

targetColumns = [ \
                 'Population', \
                 'Life Expectancy', \
                 'GDP (PPP) in US $','Area (sq km)', \
                 'Land Boundaries (km)', \
                 'Coastline (km)', \
                 'Literacy Rate', \
                 'Health Expenditure/GDP', \
                 'Military Expenditure/GDP', \
                 'Renewable Water Resources (cu km)', \
                 'Net Migration Rate/1000 Population', \
                 'Labor Force', \
                 'Internet Users (circa 2009)', \
                 'Commercial Prime Lending Rate'
                 ]
dfCorrCoeff = pd.DataFrame(data=None, columns=['Column1','Column2','Correlation','pValue'])
#print(dfCountries['Population'].corr(dfCountries['Life Expectancy']))

for i in arange(size(targetColumns)):
    #print(i)
    for j in arange(i+1,size(targetColumns),1):
        corelCoeff = dfCountries[targetColumns[i]].corr(dfCountries[targetColumns[j]])
        if(corelCoeff < 0): corelCoeff = corelCoeff * -1
        temp = np.asarray([targetColumns[i],targetColumns[j],corelCoeff,0])
        dfCorrCoeff.loc[len(dfCorrCoeff)+1] = temp
#print(dfCorrCoeff.sort(columns='Correlation'))
print("Result")
res = dfCorrCoeff.sort(columns='Correlation')
wkCor = res.head(n=1)
#print(wkCor[['Column1']])
#print (wkCor[['Column1']] + " and")
#print ("%s" % wkCor[['Column1']] +" and "+ wkCor[['Column2']] +" are weekly correlated with correation coefficient of : "+\
#       wkCor[['Correlation']])
print("\nWeekest Correlation: ")
print (res.head(n=1))
print("\nStrongest Correlation: ")
print (res.tail(n=1))
# Out:
# Task 2
#
# Result
# Weekest Correlation:
#               Column1                   Column2       Correlation pValue
# 31  GDP (PPP) in US $  Military Expenditure/GDP  0.00197994977101      0
#
# Strongest Correlation:
#        Column1      Column2     Correlation pValue
# 11  Population  Labor Force  0.980395563165      0

# %%
def shuffleAndCorr(df, orgCorr, runs=1, threshold=0.2, axis=0):     
    df_sh = df.copy()
    success_count = 0
    for _ in range(runs):
        df_sh.apply(np.random.shuffle, axis=axis)
        newCor = df_sh['Col1'].corr(df_sh['Col2'])
        if (newCor < 0): newCor = newCor * -1
        #print(newCor)
        diff = newCor - orgCorr
        if (diff < 0): diff = diff * -1
        #print("diff %f" % diff)
        if (diff < threshold): success_count = success_count + 1
    #print success_count
    p = success_count / runs
    return p
pValue = np.zeros(len(res))
ctr = 0
for i in arange(size(targetColumns)): #arange(2):# arange(size(targetColumns)):
    for j in arange(i+1,size(targetColumns),1): #arange(i+1,2,1): #arange(i+1,size(targetColumns),1):
        orgCorr = dfCountries[targetColumns[i]].corr(dfCountries[targetColumns[j]])
        temp_df = pd.DataFrame({'Col1':dfCountries[targetColumns[i]], \
                                'Col2':dfCountries[targetColumns[j]], \
                                'orgCorr':orgCorr, \
                                'pValue':0})
        #print "Org Corr: %f" % orgCorr
        res[ (res['Column1']==targetColumns[i]) & (res['Column2']==targetColumns[j]) ]['pValue'] \
        = shuffleAndCorr(temp_df, orgCorr, 10, 0.20)
print(res)
# Out:
#                                Column1                             Column2  \
# 31                   GDP (PPP) in US $            Military Expenditure/GDP
# 68                       Literacy Rate                         Labor Force
# 10                          Population  Net Migration Rate/1000 Population
# 86  Net Migration Rate/1000 Population                         Labor Force
# 50                Land Boundaries (km)            Military Expenditure/GDP
# 1                           Population                     Life Expectancy
# 82   Renewable Water Resources (cu km)  Net Migration Rate/1000 Population
# 80            Military Expenditure/GDP         Internet Users (circa 2009)
# 15                     Life Expectancy                        Area (sq km)
# 23                     Life Expectancy                         Labor Force
# 78            Military Expenditure/GDP  Net Migration Rate/1000 Population
# 41                        Area (sq km)            Military Expenditure/GDP
# 85   Renewable Water Resources (cu km)       Commercial Prime Lending Rate
# 52                Land Boundaries (km)  Net Migration Rate/1000 Population
# 87  Net Migration Rate/1000 Population         Internet Users (circa 2009)
# 6                           Population                       Literacy Rate
# 72              Health Expenditure/GDP   Renewable Water Resources (cu km)
# 79            Military Expenditure/GDP                         Labor Force
# 8                           Population            Military Expenditure/GDP
# 39                        Area (sq km)                       Literacy Rate
# 76              Health Expenditure/GDP       Commercial Prime Lending Rate
# 74              Health Expenditure/GDP                         Labor Force
# 20                     Life Expectancy            Military Expenditure/GDP
# 40                        Area (sq km)              Health Expenditure/GDP
# 21                     Life Expectancy   Renewable Water Resources (cu km)
# 33                   GDP (PPP) in US $  Net Migration Rate/1000 Population
# 55                Land Boundaries (km)       Commercial Prime Lending Rate
# 77            Military Expenditure/GDP   Renewable Water Resources (cu km)
# 46                        Area (sq km)       Commercial Prime Lending Rate
# 7                           Population              Health Expenditure/GDP
# ..                                 ...                                 ...
# 22                     Life Expectancy  Net Migration Rate/1000 Population
# 28                   GDP (PPP) in US $                      Coastline (km)
# 36                   GDP (PPP) in US $       Commercial Prime Lending Rate
# 16                     Life Expectancy                Land Boundaries (km)
# 70                       Literacy Rate       Commercial Prime Lending Rate
# 25                     Life Expectancy       Commercial Prime Lending Rate
# 59                      Coastline (km)   Renewable Water Resources (cu km)
# 9                           Population   Renewable Water Resources (cu km)
# 83   Renewable Water Resources (cu km)                         Labor Force
# 3                           Population                        Area (sq km)
# 44                        Area (sq km)                         Labor Force
# 32                   GDP (PPP) in US $   Renewable Water Resources (cu km)
# 84   Renewable Water Resources (cu km)         Internet Users (circa 2009)
# 27                   GDP (PPP) in US $                Land Boundaries (km)
# 38                        Area (sq km)                      Coastline (km)
# 54                Land Boundaries (km)         Internet Users (circa 2009)
# 45                        Area (sq km)         Internet Users (circa 2009)
# 4                           Population                Land Boundaries (km)
# 53                Land Boundaries (km)                         Labor Force
# 26                   GDP (PPP) in US $                        Area (sq km)
# 51                Land Boundaries (km)   Renewable Water Resources (cu km)
# 2                           Population                   GDP (PPP) in US $
# 18                     Life Expectancy                       Literacy Rate
# 34                   GDP (PPP) in US $                         Labor Force
# 37                        Area (sq km)                Land Boundaries (km)
# 42                        Area (sq km)   Renewable Water Resources (cu km)
# 12                          Population         Internet Users (circa 2009)
# 89                         Labor Force         Internet Users (circa 2009)
# 35                   GDP (PPP) in US $         Internet Users (circa 2009)
# 11                          Population                         Labor Force
#
#          Correlation pValue
# 31  0.00197994977101      0
# 68   0.0083318444573      0
# 10    0.011877794873      0
# 86   0.0122300367894      0
# 50   0.0139458280266      0
# 1      0.01424900493      0
# 82   0.0252262106817      0
# 80   0.0262750876651      0
# 15   0.0330224768662      0
# 23   0.0336099331333      0
# 78    0.034644264368      0
# 41   0.0354951335266      0
# 85   0.0358134649236      0
# 52   0.0377832303538      0
# 87   0.0423419092675      0
# 6    0.0424641125247      0
# 72    0.042977373617      0
# 79   0.0476616028141      0
# 8    0.0487971565219      0
# 39   0.0518188403137      0
# 76    0.053952944809      0
# 74   0.0566533208076      0
# 20   0.0635721621409      0
# 40    0.064266908543      0
# 21   0.0655556569667      0
# 33   0.0658184542247      0
# 55   0.0658469612419      0
# 77   0.0670063150678      0
# 46   0.0672431074179      0
# 7    0.0703422076813      0
# ..               ...    ...
# 22    0.199588545754      0
# 28    0.204549279989      0
# 36    0.208970449887      0
# 16     0.21949380457      0
# 70    0.291634029818      0
# 25    0.374315618311      0
# 59    0.377032855233      0
# 9     0.436185023192      0
# 83    0.446817286799      0
# 3     0.453228160083      0
# 44    0.477219209609      0
# 32    0.480120775954      0
# 84    0.484003154408      0
# 27    0.500612372659      0
# 38    0.521335672386      0
# 54    0.524125381849      0
# 45    0.564210389523      0
# 4     0.575145694196      0
# 53    0.581192278516      0
# 26    0.592457511035      0
# 51    0.672145778487      0
# 2     0.697699022485      0
# 18    0.724784290212      0
# 34    0.730545328238      0
# 37    0.749097847537      0
# 42    0.760766323437      0
# 12    0.761484364562      0
# 89    0.831730316538      0
# 35    0.939309560166      0
# 11    0.980395563165      0
#
# [91 rows x 4 columns]
# -c:23: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead

# %%
#Do a permutation test to determine the p-value of 
#each observed correlation to test which are significant 
#(what fraction of permutations produce at least this high a correlation).

# %%
import random
import numpy as np

a = np.arange(10)
np.random.shuffle(a)
print a
# Out:
#   File "<ipython-input-103-ad5e615a667a>", line 6
#     print a
#           ^
# SyntaxError: invalid syntax

# %%
def shuffle(df, n=1, axis=0):     
    df_sh = df.copy()
    for _ in range(n):
        df_sh.apply(np.random.shuffle, axis=axis)
    return df_sh

df = pd.DataFrame({'A':range(10), 'B':range(10)})
print df
shuffle(df, 5)

# %%
print(res)

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
from math import sin, cos, sqrt, atan2, radians

#distance calculations
def findDistance(lat1,lon1,lat2,lon2,R=6373.0):
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = (sin(dlat/2))**2 + cos(lat1) * cos(lat2) * (sin(dlon/2))**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    distance = R * c
    return distance

print ("Task 5\n")
#Read csv File into dataFrame
dfCountries = pd.read_csv('country-data.csv')

#Build a pairwise countries DataFrame
targetColumns = [ \
                 'Country Name', \
                 'Latitude of Capital', \
                 'Longitude of Capital'\
                ]
dfDistance = pd.DataFrame(data=None, columns=['Country1','Country2','Distance',\
                                              'PopulationDiff','literacyDiff','GDPDiff',\
                                              'LifeExpDiff','HealthDiff','MilitaryDiff','WaterDiff'])
#dfDistance = pd.DataFrame({'Country1','Country2','Distance':dtype='float32'])
                                              
#Loop through to fill the distance column of dfDistance
#print(len(dfCountries.index))
#print(dfCountries.loc[0,targetColumns])
for i in arange(len(dfCountries.index)):#arange(5): #
    src_country = dfCountries.loc[i,targetColumns[0]]
    src_lat = dfCountries.loc[i,targetColumns[1]]
    src_lon = dfCountries.loc[i,targetColumns[2]]
    #print(i)
    for j in arange(len(dfCountries.index)): #arange(5):#arange(i+1,5,1): #
        dest_country = dfCountries.loc[j,targetColumns[0]]
        dest_lat = dfCountries.loc[j,targetColumns[1]]
        dest_lon = dfCountries.loc[j,targetColumns[2]]
        lat1 = math.radians(conversion(str(src_lat)))
        lon1 = math.radians(conversion(str(src_lon)))
        lat2 = math.radians(conversion(str(dest_lat)))
        lon2 = math.radians(conversion(str(dest_lon)))
        
        popDiff = long(dfCountries[dfCountries['Country Name']==src_country]['Population']) - long(dfCountries[dfCountries['Country Name']==dest_country]['Population'])
        literacyDiff = long(dfCountries[dfCountries['Country Name']==src_country]['Literacy Rate']) - long(dfCountries[dfCountries['Country Name']==dest_country]['Literacy Rate'])
        gdpDiff = long(dfCountries[dfCountries['Country Name']==src_country]['GDP (PPP) in US $']) - long(dfCountries[dfCountries['Country Name']==dest_country]['GDP (PPP) in US $'])
        lifeDiff = long(dfCountries[dfCountries['Country Name']==src_country]['Life Expectancy']) - long(dfCountries[dfCountries['Country Name']==dest_country]['Life Expectancy'])
        healthDiff = long(dfCountries[dfCountries['Country Name']==src_country]['Health Expenditure/GDP']) - long(dfCountries[dfCountries['Country Name']==dest_country]['Health Expenditure/GDP'])
        militaryDiff = long(dfCountries[dfCountries['Country Name']==src_country]['Military Expenditure/GDP']) - long(dfCountries[dfCountries['Country Name']==dest_country]['Military Expenditure/GDP'])
        waterDiff = long(dfCountries[dfCountries['Country Name']==src_country]['Renewable Water Resources (cu km)']) - long(dfCountries[dfCountries['Country Name']==dest_country]['Renewable Water Resources (cu km)'])
        #print(popDiff)
        temp = np.asarray([src_country, dest_country,float(findDistance(lat1,lon1,lat2,lon2)), popDiff,literacyDiff,gdpDiff,lifeDiff,healthDiff,militaryDiff,waterDiff])
        dfDistance.loc[len(dfDistance)+1] = temp
        #print(src_country, dest_country,findDistance(lat1,lon1,lat2,lon2))
dfDistance = dfDistance[dfDistance['Country1']!=dfDistance['Country2']].sort(columns='Distance')
print ("Distance Table")
dfDistance.head()
        #Distance Computation
        #distance = 
        #if(corelCoeff < 0): corelCoeff = corelCoeff * -1
        #temp = np.asarray([targetColumns[i],targetColumns[j],corelCoeff,0])
        #dfCorrCoeff.loc[len(dfCorrCoeff)+1] = temp
# Out:
# Task 5
#
# Distance Table
#            Country1  Country2       Distance PopulationDiff literacyDiff  \
# 10485       Germany    Serbia  1000.06293466       73786921            1
# 11020       Grenada  Suriname  1000.41624493        -463159            2
# 15112    Madagascar   Uruguay  10000.4334342       19868954          -34
# 13708  Korea, South     Spain  10000.7961511        1302045            0
# 11530        Guyana     Syria  10003.6350445      -17216085            7
#
#              GDPDiff LifeExpDiff HealthDiff MilitaryDiff WaterDiff
# 10485  3149530000000           5          1           -1        -8
# 11020    -5662000000           2          1            0       -57
# 15112   -34240000000         -11         -4           -1       198
# 13708   280000000000          -2         -2            2       -42
# 11530  -101407000000          -1          2           -2       225

# %%
print("Shortest Distance Table")
dfShor = dfDistance.groupby('Country1').first()
dfShor
# Out:
# Shortest Distance Table
#                                      Country2       Distance PopulationDiff  \
# Country1
# Afghanistan                             India  1004.52935574    -1204521783
# Albania                                Brunei   10077.844072        2597534
# Algeria                               Uruguay  10044.9164848       35480750
# Andorra                        United Kingdom  1008.33237874      -63657519
# Angola                              Singapore  10102.1974664       13520805
# Antigua and Barbuda                   Georgia  10069.1891404       -4844585
# Argentina                               Spain  10062.3565332       -4713567
# Armenia                 Saint Kitts and Nevis  10164.5496927        3009093
# Australia                          Seychelles  10047.7050322       22415967
# Austria                             Guatemala   10005.525866       -6424021
# Azerbaijan              Saint Kitts and Nevis  10563.4149355        9634672
# Bahamas, The                           Cyprus  10123.7493396        -850624
# Bahrain                                Canada  10378.2165191      -33520752
# Bangladesh                     Western Sahara  10061.8182854      165725917
# Barbados                          South Sudan  10021.6852892      -11273015
# Belarus                                Belize  10074.4444922        9267214
# Belgium                               Bolivia  10252.4975487        -182125
# Belize                                  Malta  10034.6047573         -71811
# Benin                             El Salvador  10035.2861577        4035044
# Bhutan                                   Mali   10099.856062      -15722260
# Bolivia                        United Kingdom  10006.3633195      -53111491
# Bosnia and Herzegovina               Honduras  10135.6584983       -4726918
# Botswana                              Vietnam   10020.501526      -91266051
# Brazil                                Romania  10018.4058974      180926917
# Brunei                                Lesotho  10029.9890709       -1519333
# Bulgaria                              Ukraine  1021.82440752      -37366697
# Burkina Faso                         Mongolia  10317.0610607       15411933
# Burma                                Portugal  10113.3521381       44932419
# Burundi                           Saint Lucia  10138.9435455       10232569
# Cabo Verde                              India   10230.848241    -1235806096
# ...                                       ...            ...            ...
# Suriname                             Tanzania  10576.5753815      -49065827
# Swaziland                         Timor-Leste  10028.9078288         218081
# Sweden                            Timor-Leste  11822.2920456        8522267
# Switzerland                           Uruguay  11089.0356732        4728544
# Syria                     Trinidad and Tobago  10070.9431178       16727723
# Taiwan                                Tunisia  10077.3621199       12422407
# Tajikistan                      United States  10727.9222092     -310840591
# Tanzania                              Uruguay  10072.7280891       46306166
# Thailand                                 Togo  10846.3649168       60390027
# Timor-Leste                          Zimbabwe   10197.350564      -12570179
# Togo                                  Vietnam   11269.324875      -86070461
# Tonga                                 Uruguay  11070.0805631       -3226532
# Trinidad and Tobago                    Zambia  10302.8103417      -13414589
# Tunisia                               Uruguay  10512.7396154        7604549
# Turkey                              Venezuela  10078.7464564       52750906
# Turkmenistan                       Uzbekistan  1002.46026489      -23757773
# Tuvalu                          United States  11792.4122937     -318881321
# Uganda                              Venezuela  11033.9519273        7050429
# Ukraine                               Uruguay  12704.8270924       40958441
# United Arab Emirates            United States  11349.7337617     -313263298
# United Kingdom                        Uruguay  11048.6415822       60410005
# United States                      Uzbekistan  10469.0849755      289962387
# Uruguay                                 Yemen  11910.2558979      -22719994
# Uzbekistan                            Vanuatu  12045.0837062       28662779
# Vanuatu                              Zimbabwe  13899.6275001      -13504784
# Venezuela                              Zambia  10863.7581499       14229981
# Vietnam                        Western Sahara  11552.0195677       92867040
# Western Sahara                          Yemen  6043.24689659      -25498171
# Yemen                                  Zambia  3843.15295701       11414461
# Zambia                               Zimbabwe  396.431991916         866784
#
#                        literacyDiff          GDPDiff LifeExpDiff HealthDiff  \
# Country1
# Afghanistan                     -34   -4944700000000         -17          6
# Albania                           1       6090000000           1          4
# Algeria                         -26     228730000000           0         -5
# Andorra                           1   -2386837000000           2         -2
# Angola                          -25    -207000000000         -29         -1
# Antigua and Barbuda               0     -25690000000           1         -4
# Argentina                         0    -619000000000          -4         -1
# Armenia                           2      19658000000          -1          0
# Australia                         8     995596000000           8          6
# Austria                          23     279490000000           9          4
# Azerbaijan                        2     102048000000          -4          1
# Bahamas, The                     -3     -10220000000          -7          0
# Bahrain                          -5   -1485040000000          -3         -8
# Bangladesh                      -26     324093500000           8         -3
# Barbados                         72      -7706000000          20          1
# Belarus                          23     146917000000           4          0
# Belgium                           8     362890000000          11          6
# Belize                          -16      -8137000000         -12         -3
# Benin                           -42     -30820000000         -13         -2
# Bhutan                           19     -13665000000          14         -2
# Bolivia                          -8   -2330890000000         -12         -5
# Bosnia and Herzegovina           13      -7070000000           6          1
# Botswana                         -8    -325000000000         -18         -1
# Brazil                           -7    2131000000000          -1          3
# Brunei                            6      17985000000          24        -10
# Bulgaria                         -1    -232000000000           5          0
# Burkina Faso                    -69       9480000000         -14          1
# Burma                            -3    -132000000000         -14         -8
# Burundi                         -23       3534000000         -18          1
# Cabo Verde                       22   -4987778000000           4          1
# ...                             ...              ...         ...        ...
# Suriname                         27     -72170000000          10         -2
# Swaziland                        29     -19151000000         -17          3
# Sweden                           41     368590000000          14          4
# Switzerland                       1     314730000000           6          2
# Syria                           -14      80860000000          -4         -2
# Taiwan                           17     818000000000           4          0
# Tajikistan                        0  -16680800000000         -12        -12
# Tanzania                        -31      23020000000         -15         -1
# Thailand                         33     665652000000          10         -4
# Timor-Leste                     -25      17914000000          12         -1
# Togo                            -33    -351652000000          -8          2
# Tonga                             1     -55424000000          -1         -3
# Trinidad and Tobago              37       1670000000          21         -1
# Tunisia                         -19      51730000000          -1         -2
# Turkey                           -1     763000000000          -1          1
# Turkmenistan                      0     -57840000000          -4         -3
# Tuvalu                          -16  -16699960000000         -14          0
# Uganda                          -22    -352630000000         -20          4
# Ukraine                           1     280730000000          -7         -1
# United Arab Emirates             -9  -16430000000000          -2        -14
# United Kingdom                    1    2333730000000           4          1
# United States                     0   16587000000000           6         12
# Uruguay                          33      -5360000000          12          3
# Uzbekistan                       16     111730000000           1          1
# Vanuatu                           0      -6226000000          17         -2
# Venezuela                        34     381530000000          23         -1
# Vietnam                          10     358093500000          10          0
# Western Sahara                   18     -60723500000          -2          1
# Yemen                             4      36160000000          13         -1
# Zambia                          -22      17974000000          -4          0
#
#                        MilitaryDiff WaterDiff
# Country1
# Afghanistan                       2     -1846
# Albania                          -1        33
# Algeria                           3      -128
# Andorra                           1       -82
# Angola                            0       148
# Antigua and Barbuda               1       -63
# Argentina                         0       703
# Armenia                           0         7
# Australia                         1       427
# Austria                           0       -34
# Azerbaijan                        1        34
# Bahamas, The                      1         0
# Bahrain                           2     -2902
# Bangladesh                       -2      1162
# Barbados                         -7       -65
# Belarus                           0        40
# Belgium                           0      -604
# Belize                            1        18
# Benin                             1         1
# Bhutan                            2       -22
# Bolivia                          -1       475
# Bosnia and Herzegovina            0       -58
# Botswana                          0      -872
# Brazil                            0      8022
# Brunei                            1         5
# Bulgaria                         -1      -118
# Burkina Faso                      0       -22
# Burma                             2      1100
# Burundi                          -1       -53
# Cabo Verde                       -2     -1911
# ...                             ...       ...
# Suriname                          2        26
# Swaziland                         1       -61
# Sweden                           -1       109
# Switzerland                      -1       -86
# Syria                             0        13
# Taiwan                            2        63
# Tajikistan                       -1     -3048
# Tanzania                          0       -43
# Thailand                          0       424
# Timor-Leste                       0        45
# Togo                             -1      -870
# Tonga                             2       -74
# Trinidad and Tobago               2      -102
# Tunisia                           0      -135
# Turkey                            1     -1022
# Turkmenistan                      0       -24
# Tuvalu                           -1     -3004
# Uganda                            0     -1167
# Ukraine                           1         0
# United Arab Emirates              1     -3069
# United Kingdom                    1         8
# United States                     1      3021
# Uruguay                          -3       137
# Uzbekistan                        0       -17
# Vanuatu                           1        45
# Venezuela                         0      1128
# Vietnam                          -1       819
# Western Sahara                   -1        63
# Yemen                             3      -103
# Zambia                           -1        85
#
# [196 rows x 9 columns]

# %%
print("Farthest Distance Table")
dfFar = dfDistance.groupby('Country1').last()
dfFar
# Out:
# Farthest Distance Table
#                 Country2       Distance PopulationDiff literacyDiff  \
# Country1
# Afghanistan       Angola  7604.40538084       12734742          -42
# Albania           Angola  5618.89700014      -16067897           26
# Algeria          Andorra  652.888900639       38728264          -28
# Andorra          Algeria  652.888900639      -38728264           28
# Angola       Afghanistan  7604.40538084      -12734742           42
#
#                    GDPDiff LifeExpDiff HealthDiff MilitaryDiff WaterDiff
# Country1
# Afghanistan   -86700000000          -5          6            1       -83
# Albania      -103660000000          22          3           -2      -107
# Algeria       281837000000          -6         -4            1       -54
# Andorra      -281837000000           6          4           -1        54
# Angola         86700000000           5         -6           -1        83

# %%
#dfCountries[dfCountries['Country Name']=='Afghanistan']['Population']

#for i in arange(5):
#        src_country = dfCountries.loc[i,targetColumns[0]]
#        print(src_country)
#dfShor.loc['Afghanistan','Country2']
# Out:
#              Country Code          Government Type Capital City  \
# Country Name
# Afghanistan            AF         Islamic republic        Kabul
# Albania                AL  parliamentary democracy       Tirana
# Algeria                DZ                 republic      Algiers
#
#              Date of Founding/Independence Latitude of Capital  \
# Country Name
# Afghanistan                      8/19/1919             34 31 N
# Albania                         11/28/1912             41 19 N
# Algeria                           7/5/1962             36 45 N
#
#              Longitude of Capital  Population  Life Expectancy  \
# Country Name
# Afghanistan               69 11 E    31822848            50.49
# Albania                   19 49 E     3020209            77.96
# Algeria                    3 03 E    38813722            76.39
#
#               GDP (PPP) in US $  Area (sq km)  Land Boundaries (km)  \
# Country Name
# Afghanistan        4.530000e+10        652230                  5987
# Albania            2.834000e+10         28748                   691
# Algeria            2.850000e+11       2381741                  6734
#
#               Coastline (km)  Literacy Rate  Health Expenditure/GDP  \
# Country Name
# Afghanistan                0           28.1                     9.6
# Albania                  362           96.8                     6.3
# Algeria                  998           72.6                     3.9
#
#               Military Expenditure/GDP  Renewable Water Resources (cu km)  \
# Country Name
# Afghanistan                       4.74                              65.33
# Albania                           1.47                              41.70
# Algeria                           4.48                              11.67
#
#               Net Migration Rate/1000 Population  Labor Force  \
# Country Name
# Afghanistan                                -1.83      7512000
# Albania                                    -3.31      1098000
# Algeria                                    -0.93     11150000
#
#               Internet Users (circa 2009)  Commercial Prime Lending Rate
# Country Name
# Afghanistan                       1000000                          15.00
# Albania                           1300000                           9.52
# Algeria                           4700000                           8.00

# %%
from math import sin, cos, sqrt, atan2, radians
def conversion(old):
    direction = {'N':-1, 'S':1, 'E': -1, 'W':1}
    new = old.split()
    new_dir = new.pop()
    new.extend([0,0,0])
    return (int(new[0])+int(new[1])/60.0+int(new[2])/3600.0) * direction[new_dir]

#distance calculations
def findDistance(lat1,lon1,lat2,lon2,R=6373.0):
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = (sin(dlat/2))**2 + cos(lat1) * cos(lat2) * (sin(dlon/2))**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    distance = R * c
    return distance

lat1 = math.radians(conversion("34 31 N"))
lon1 = math.radians(conversion("69 11 E"))
lat2 = math.radians(conversion("41 19 N"))
lon2 = math.radians(conversion("19 49 E"))
#print(af_lat,af_long)
print(findDistance(lat1,lon1,lat2,lon2))

# %% [markdown]
# ####Linear Regresssion
# ##### GDP versus Health Expenditure/GDP
# ##### GDP versus net Migration

# %%
import numpy as np
from __future__ import print_function
import prettyplotlib as ppl
import matplotlib as mpl
import pandas as pd
from pandas import Series, DataFrame
from mpl_toolkits.basemap import Basemap

fig, axes = plt.subplots(1, 2, figsize=(12,4))
df_reg = dfCountries.copy()
df_reg['GDP'] = dfCountries['GDP (PPP) in US $'].astype(float) / (1e12)
df_reg['HealthExpenditure/GDP'] = dfCountries['Health Expenditure/GDP'].astype(float)
df_reg['Internet Users (circa 2009)'] = dfCountries['Internet Users (circa 2009)'].astype(float) / (1e9)

#Health Expenditure/GDP
x = df_reg['Health Expenditure/GDP']
N=len(x)
y = df_reg['GDP']
#x = np.arange(N)
area =  np.pi * (8 * health/10)**2
colors = np.random.rand(N)
ppl.scatter(axes[0],x,y,s=area, c=colors, alpha=0.5)
axes[0].set_title("Health Expenditure/GDP - Scatter Plot\n (Area of the circle proportional\n to the Health Expenditure/GDP)\n")
axes[0].set_ylabel('GDP')
axes[0].set_xlabel('Health Expenditure/GDP')

#Net Migration Rate/1000 Population
x = df_reg['Internet Users (circa 2009)']
N = len(x)
area =  np.pi * (8 * netMigration+50)**2
colors = np.random.rand(N)
ppl.scatter(axes[1],x,y,s=area/600, c=colors, alpha=0.5)
axes[1].set_title("Internet Users (circa 2009) - Scatter Plot\n (Area of the circle proportional\n to the Internet Users (circa 2009))\n")
axes[1].set_xlabel('Internet Users (circa 2009)')
axes[1].set_ylabel('GDP')

# %%
trainSize = 160 #80:20 Rule of Data Mining
health_train = df_reg['Health Expenditure/GDP'][:trainSize]
health_test = df_reg['Health Expenditure/GDP'][trainSize:]
internet_train = df_reg['Internet Users (circa 2009)'][:trainSize]
internet_test = df_reg['Internet Users (circa 2009)'][trainSize:]
# Out:
# 0      9.6
# 1      6.3
# 2      3.9
# 3      7.2
# 4      3.5
# 5      5.9
# 6      8.1
# 7      4.3
# 8      9.0
# 9     10.6
# 10     5.2
# 11     7.7
# 12     3.8
# 13     3.7
# 14     7.7
# ...
# 145     4.4
# 146     7.2
# 147     4.9
# 148     7.0
# 149     7.2
# 150     7.7
# 151     3.7
# 152     6.0
# 153    10.4
# 154     3.8
# 155    18.8
# 156     4.6
# 157     9.0
# 158     9.0
# 159     8.8
# Name: Health Expenditure/GDP, Length: 160, dtype: float64
