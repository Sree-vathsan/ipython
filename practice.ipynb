# %%
print "This iz python"
# Out:
# This iz python

# %%
import numpy as np
from __future__ import print_function

# %%
# a vector: the argument to the array function is a Python list
v = np.array([11, 12, 13, 14])
print('v =\n{}'.format(v))
# a matrix: the argument to the array function is a nested Python list
M = np.array([[2, 1], [3, 4]])
print('M =\n{}'.format(M))
print (type(v), type(M))
# Out:
# v =
# [11 12 13 14]
# M =
# [[2 1]
#  [3 4]]
# <type 'numpy.ndarray'> <type 'numpy.ndarray'>

# %%
print("v shape is {}".format(v.shape))
print("M shape is {}".format(M.shape))
print("Data type of v is {}".format(v.dtype))
print()
print("M transpose =\n{}".format(M.T))
print()

M.sort(axis=0)
print("M sorted by column =\n{}".format(np.asarray(M)))
print()
# Out:
# v shape is (4L,)
# M shape is (2L, 2L)
# Data type of v is int32
#
# M transpose =
# [[1 3]
#  [2 4]]
#
# M sorted by column =
# [[1 2]
#  [3 4]]

# %%
print("v[0] = {}\n".format(v[0]))
print("M =\n{}\n".format(M))
print("M[1, 1] = {}\n".format(M[1,1]))
print("M[1] = {}\n".format(M[1]))
print("M[1, :] = {}\n".format(M[1, :]))
print("M[:, 1] = {}\n".format(M[:, 1]))
print("M[1, :] = 0")
M[1, :] = 0
print("M =\n{}\n".format(M))
# Out:
# v[0] = 11
#
# M =
# [[1 2]
#  [3 4]]
#
# M[1, 1] = 4
#
# M[1] = [3 4]
#
# M[1, :] = [3 4]
#
# M[:, 1] = [2 4]
#
# M[1, :] = 0
# M =
# [[1 2]
#  [0 0]]

# %%
import pandas.io.data
df = pd.read_csv('country-data.csv', index_col='Country Name')
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3b13b86881ff> in <module>()
#       1 import pandas.io.data
# ----> 2 df = pd.read_csv('country-data.csv', index_col='Country Name')
#       3 df.head()
#
# NameError: name 'pd' is not defined

# %%
from pylab import *

n = 1024
X = np.random.normal(0,1,n)
Y = np.random.normal(0,1,n)
colors = np.random.rand(n)
area =  np.pi * (15 * np.random.rand(n))**2
scatter(X,Y,s=area, c=colors, alpha=0.5)
show()

# %%
print ("Hello")

# %%
import pandas as pd
from pandas import Series, DataFrame
#Read csv File into dataFrame
dfCountries = pd.read_csv('country-data.csv')
dfCountries.replace(to_replace='unknown',value='NaN',inplace=True)
dfCountries.fillna(dfCountries.mean(),inplace=True)
#print(dfCountries.mean())
#print(dfCountries['Population'])
dfCountries.head()
# Out:
#   Country Name Country Code          Government Type      Capital City  \
# 0  Afghanistan           AF         Islamic republic             Kabul
# 1      Albania           AL  parliamentary democracy            Tirana
# 2      Algeria           DZ                 republic           Algiers
# 3      Andorra           AD  parliamentary democracy  Andorra la Vella
# 4       Angola           AO                 republic            Luanda
#
#   Date of Founding/Independence Latitude of Capital Longitude of Capital  \
# 0                     8/19/1919             34 31 N              69 11 E
# 1                    11/28/1912             41 19 N              19 49 E
# 2                      7/5/1962             36 45 N               3 03 E
# 3                          1278             42 30 N               1 31 E
# 4                    11/11/1975              8 50 S              13 13 E
#
#    Population  Life Expectancy  GDP (PPP) in US $        ...          \
# 0    31822848            50.49       4.530000e+10        ...
# 1     3020209            77.96       2.834000e+10        ...
# 2    38813722            76.39       2.850000e+11        ...
# 3       85458            82.65       3.163000e+09        ...
# 4    19088106            55.29       1.320000e+11        ...
#
#    Land Boundaries (km)  Coastline (km)  Literacy Rate  \
# 0                  5987               0           28.1
# 1                   691             362           96.8
# 2                  6734             998           72.6
# 3                   118               0          100.0
# 4                  5369            1600           70.4
#
#    Health Expenditure/GDP  Military Expenditure/GDP  \
# 0                     9.6                      4.74
# 1                     6.3                      1.47
# 2                     3.9                      4.48
# 3                     7.2                       NaN
# 4                     3.5                      3.63
#
#   Renewable Water Resources (cu km) Net Migration Rate/1000 Population  \
# 0                             65.33                              -1.83
# 1                              41.7                              -3.31
# 2                             11.67                              -0.93
# 3                               NaN                               0.00
# 4                               148                               0.47
#
#    Labor Force Internet Users (circa 2009)  Commercial Prime Lending Rate
# 0      7512000                     1000000                             15
# 1      1098000                     1300000                           9.52
# 2     11150000                     4700000                              8
# 3        36060                       67100                            NaN
# 4      9018000                      606700                             15
#
# [5 rows x 21 columns]
